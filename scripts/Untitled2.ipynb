# %%
set xlabel 'Fraction of users'
set ylabel 'Average latency (ms)'
set key bottom right
plot 'fairness-perf-csf.tsv' using ($2*1000):(100-$1) with lines t 'static', '' using (100-$1):($3*1000) w lines t 'max-min', '' using (100-$1):($4*1000) w lines t 'Karma (a=1)', '' using (100-$1):($9*1000) w lines t 'Karma (a=0.5)', '' using (100-$1):($14*1000) w lines t 'Karma (a=0)'
# Out:
# ...
# [?
